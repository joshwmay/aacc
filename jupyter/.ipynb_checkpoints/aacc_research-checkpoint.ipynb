# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.float_format = '{:20,.2f}'.format

# %%
_25 = pd.read_csv("over_25.csv")
_reg19 = pd.read_csv("ugp_reg_2019.csv")
_tui = pd.read_csv("tuition.csv")
_enr = pd.read_csv("enrollment.csv")
_sals = pd.read_csv("sals.csv")
_25.dropna(inplace = True)

# %%
sals = _sals.fillna(0)
sals.head(16)
# Out:
#                           Institution  Professor  Associate Professor  \
# 0        Allegany College of Maryland      68834                58677
# 1                     Garrett College      71250                59249
# 2           Carroll Community College      78094                70470
# 3           Wor-Wic Community College      81320                71653
# 4        Hagerstown Community College      81758                65300
# 5           Harford Community College      82604                66984
# 6    Baltimore City Community College      83069                70978
# 7                       Cecil College      83702                66154
# 8                  Chesapeake College      84311                76841
# 9         Frederick Community College      87668                71675
# 10  Prince George’s Community College      89431                75880
# 11     Anne Arundel Community College      90671                78391
# 12          Community College Average      92067                77151
# 13       College of Southern Maryland      93391                74440
# 14           Howard Community College      94502                79237
# 15                 Montgomery College      95673                78782
#
#     Assistant Professor Instructor Lecturer   CAMPUS AVG             calc avg
# 0                 53402      48675        -        58111            57,397.00
# 1                 59522          -        0        65600            63,340.33
# 2                 56142      48416    56740        62214            61,972.40
# 3                 60874      58178        -        66401            68,006.25
# 4                 61845      55137        -        64653            66,010.00
# 5                 58968          -        -        63963            69,518.67
# 6                 62252          -        -        69942            72,099.67
# 7                 60684      43650        -        68616            63,547.50
# 8                 70585      59868        -        71794            72,901.25
# 9                 63551          -        -        73286            74,298.00
# 10                69227      53850        -        80123            72,097.00
# 11                68118      60682        -        77445            74,465.50
# 12                66741      58926    56740        78362            70,325.00
# 13                68806      63820        -        84469            75,114.25
# 14                71153      64966        -        81494            77,464.50
# 15                73840      70308        -        91251            79,650.75

# %%
def set_index(df, bool1, bool2, index):
    # Resets index of dataframe to specified number
    # Includes 'drop' and 'inplace' specifiers
    df.reset_index(drop=bool1, inplace=bool2)
    df.index += index  
    return df

# %%
_reg19["%hsp"] = _reg19["Hispanic/Latino, any race"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%blk"] = _reg19["Black/African American"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%ntv"] = _reg19["American Indian or Alaska Native"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%npi"] = _reg19["Native Hawaiian or Pacific Islander"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%asn"] = _reg19["Asian"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%wht"] = _reg19["White"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%_x2"] = _reg19["Two or More Races"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%nra"] = _reg19["Foreign/Non-Resident Alien"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%unk"] = _reg19["Unknown"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%m"] = _reg19["Male"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%f"] = _reg19["Female"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%lower"] = _reg19["Lower Division Certificate"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%assc"] = _reg19["Associate"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%bach"] = _reg19["Bachelor's"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%mstr"] = _reg19["Master's"].div(_reg19["Students"].values, fill_value=0) * 100
_reg19["%doct"] = _reg19["Doctorate"].div(_reg19["Students"].values, fill_value=0) * 100

deg_perc = set_index(_reg19.filter(['Institution','INST','Students','%lower','%assc', '%bach', 
                           '%mstr', '%doct'], axis=1).sort_values(by="Students", ascending=False, inplace=False),True, True, 1)

comcol = set_index(deg_perc.loc[deg_perc['INST'] == "CC"], True, True, 1)
pd.options.display.float_format = '{:2,.2%}'.format
comcol.head(10)
# Out:
#                               Institution INST  Students  %lower     %assc  \
# 1                      Montgomery College   CC     21260 105.36% 1,316.09%
# 2   Community College of Baltimore County   CC     17732 419.02% 1,085.61%
# 3          Anne Arundel Community College   CC     12655 546.03% 1,382.06%
# 4       Prince George's Community College   CC     11788  72.96%   927.21%
# 5                Howard Community College   CC      9110  91.11% 1,487.38%
# 6            College of Southern Maryland   CC      6351 991.97% 1,458.04%
# 7             Frederick Community College   CC      6129 236.58% 1,406.43%
# 8               Harford Community College   CC      5705  91.15% 1,423.31%
# 9        Baltimore City Community College   CC      4909 325.93%   782.24%
# 10           Hagerstown Community College   CC      3848 410.60% 1,538.46%
#
#     %bach  %mstr  %doct
# 1   0.00%  0.00%  0.00%
# 2   0.00%  0.00%  0.00%
# 3   0.00%  0.00%  0.00%
# 4   0.00%  0.00%  0.00%
# 5   0.00%  0.00%  0.00%
# 6   0.00%  0.00%  0.00%
# 7   0.00%  0.00%  0.00%
# 8   0.00%  0.00%  0.00%
# 9   0.00%  0.00%  0.00%
# 10  0.00%  0.00%  0.00%

# %%
def top_(str1, str2, df, num):
    sub = str1
    sub = df.filter(['Institution','INST','Students',str2,"%" + str1], axis=1).sort_values(by="%" + str1, ascending=False, inplace=False, na_position='last')
    sub = set_index(sub, True, True, 1)
    return sub.head(num)

hsp = top_("hsp", "Hispanic/Latino, any race", _reg19, 10)
blk = top_("blk", "Black/African American", _reg19, 10)
ntv = top_("ntv", "American Indian or Alaska Native", _reg19, 10)
npi = top_("npi", "Native Hawaiian or Pacific Islander", _reg19, 10)
asn = top_("asn", "Asian", _reg19, 10)
wht = top_("wht", "White", _reg19, 10)
_x2 = top_("_x2", "Two or More Races", _reg19, 10)
nra = top_("nra", "Foreign/Non-Resident Alien", _reg19, 10)
unk = top_("unk", "Unknown", _reg19, 10)
male = top_("m", "Male", _reg19, 10)
female = top_("f", "Female", _reg19, 10)
npi.head()
# Out:
#                             Institution INST  Students  \
# 1  University of Maryland Global Campus   4Y     58281
# 2           Mount St. Mary's University  IND      2362
# 3               University of Baltimore   4Y      4476
# 4          College of Southern Maryland   CC      6351
# 5                    Montgomery College   CC     21260
#
#    Native Hawaiian or Pacific Islander   %npi
# 1                           39,300.00% 67.43%
# 2                            1,300.00% 55.04%
# 3                            1,400.00% 31.28%
# 4                            1,800.00% 28.34%
# 5                            5,500.00% 25.87%

# %%
fp = _x2['%_x2']
inst = _x2['Institution']
plt.plot(inst,fp,marker="o")

# %%
_tui['avg'] = _tui[['FY 17', 'FY 18' , 'FY 19' , 'FY 20' , 'FY 21' ]].mean(axis=1)/100
_tui["1yr Change"] = pd.to_numeric(_tui["1yr Change"])
_tui["5yr Change"] = pd.to_numeric(_tui["5yr Change"])
_tui = _tui.sort_values(by="avg", ascending=True, inplace=False, na_position='last')
_tui = set_index(_tui, True, True, 1)
pd.options.display.float_format = '{:20,.2f}'.format
_tui.head()
# Out:
#                         Institution  FY 17  FY 18  FY 19  FY 20  FY 21  \
# 1         Wor-Wic Community College    123    125    135    139    146
# 2      Hagerstown Community College    131    133    136    143    139
# 3  Baltimore City Community College    135    133    133    140    146
# 4    Anne Arundel Community College    134    137    139    143    147
# 5                   Garrett College    135    141    146    149    142
#
#                5yr AVG           1yr Change           5yr Change  \
# 1               133.60                 0.01                 0.19
# 2               136.40                -0.03                 0.06
# 3               137.40                 0.04                 0.08
# 4               140.00                 0.03                 0.10
# 5               142.60                -0.05                 0.05
#
#                    avg
# 1                 1.34
# 2                 1.36
# 3                 1.37
# 4                 1.40
# 5                 1.43

# %%
_tui = _tui.sort_values(by="5yr Change", ascending=True, inplace=False, na_position='last')
_tui.reset_index(drop=True, inplace=True)

_tui.index += 1    
_tui.head(13)
# Out:
#                               Institution  FY 17  FY 18  FY 19  FY 20  FY 21  \
# 1       Prince George's Community College    152    157    157    157    154
# 2                           Cecil College    157    159    150    155    159
# 3   Community College of Baltimore County    160    163    163    166    167
# 4                         Garrett College    135    141    146    149    142
# 5            Hagerstown Community College    131    133    136    143    139
# 6                      Chesapeake College    151    154    159    162    162
# 7               Carroll Community College    160    163    163    166    172
# 8                      Montgomery College    163    166    173    177    177
# 9        Baltimore City Community College    135    133    133    140    146
# 10               Howard Community College    156    162    164    166    170
# 11         Anne Arundel Community College    134    137    139    143    147
# 12            Frederick Community College    142    146    149    153    156
# 13           College of Southern Maryland    148    154    159    164    164
#
#                 5yr AVG           1yr Change           5yr Change  \
# 1                155.40                -0.02                 0.01
# 2                156.00                 0.03                 0.01
# 3                163.80                 0.01                 0.04
# 4                142.60                -0.05                 0.05
# 5                136.40                -0.03                 0.06
# 6                157.60                 0.00                 0.07
# 7                164.80                 0.04                 0.07
# 8                171.20                -0.00                 0.08
# 9                137.40                 0.04                 0.08
# 10               163.60                 0.02                 0.09
# 11               140.00                 0.03                 0.10
# 12               149.20                 0.02                 0.10
# 13               157.80                 0.00                 0.11
#
#                     avg
# 1                  1.55
# 2                  1.56
# 3                  1.64
# 4                  1.43
# 5                  1.36
# 6                  1.58
# 7                  1.65
# 8                  1.71
# 9                  1.37
# 10                 1.64
# 11                 1.40
# 12                 1.49
# 13                 1.58

# %%
cm = sns.light_palette("green", as_cmap=True)
dem_perc = _reg19.filter(['Institution','INST','Students','%hsp','%blk', '%ntv', 
                           '%npi', '%asn', '%wht', '%_x2','%nra','%unk','%m', '%f'], axis=1)
dem_perc = dem_perc.loc[dem_perc['INST'] == "CC"]
dem_perc = set_index(dem_perc.sort_values(by="Students", ascending=False, inplace=False, na_position='last'), True, True, 1)

dem_perc.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col2 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col3 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col4 {
#             background-color:  #9fd89f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col5 {
#             background-color:  #93d193;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col6 {
#             background-color:  #148b14;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col7 {
#             background-color:  #048204;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col8 {
#             background-color:  #b1e2b1;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col9 {
#             background-color:  #a0d9a0;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col10 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col11 {
#             background-color:  #d8f8d8;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col12 {
#             background-color:  #3ea23e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row0_col13 {
#             background-color:  #a7dda7;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col2 {
#             background-color:  #279527;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col3 {
#             background-color:  #b0e1b0;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col4 {
#             background-color:  #7ac47a;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col5 {
#             background-color:  #80c780;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col6 {
#             background-color:  #1c8f1c;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col7 {
#             background-color:  #6ebd6e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col8 {
#             background-color:  #82c882;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col9 {
#             background-color:  #79c379;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col10 {
#             background-color:  #59b159;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col11 {
#             background-color:  #c2ebc2;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col12 {
#             background-color:  #9dd79d;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row1_col13 {
#             background-color:  #49a849;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col2 {
#             background-color:  #5fb55f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col3 {
#             background-color:  #92d192;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col4 {
#             background-color:  #bee9be;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col5 {
#             background-color:  #8bcd8b;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col6 {
#             background-color:  #72bf72;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col7 {
#             background-color:  #8fcf8f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col8 {
#             background-color:  #51ad51;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col9 {
#             background-color:  #45a645;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col10 {
#             background-color:  #c2ecc2;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col11 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col12 {
#             background-color:  #7fc67f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row2_col13 {
#             background-color:  #67b967;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col2 {
#             background-color:  #69ba69;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col3 {
#             background-color:  #6bbb6b;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col4 {
#             background-color:  #178c17;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col5 {
#             background-color:  #9ad59a;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col6 {
#             background-color:  #85ca85;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col7 {
#             background-color:  #91d091;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col9 {
#             background-color:  #9ed89e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col10 {
#             background-color:  #90d090;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col11 {
#             background-color:  #a2daa2;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col12 {
#             background-color:  #a2daa2;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row3_col13 {
#             background-color:  #44a544;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col2 {
#             background-color:  #87cb87;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col3 {
#             background-color:  #82c882;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col4 {
#             background-color:  #95d395;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col5 {
#             background-color:  #a8dda8;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col6 {
#             background-color:  #72bf72;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col7 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col8 {
#             background-color:  #95d395;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col9 {
#             background-color:  #098509;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col10 {
#             background-color:  #69ba69;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col11 {
#             background-color:  #5eb45e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col12 {
#             background-color:  #6fbd6f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row4_col13 {
#             background-color:  #77c277;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col2 {
#             background-color:  #a6dca6;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col3 {
#             background-color:  #a5dba5;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col4 {
#             background-color:  #9fd89f;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col5 {
#             background-color:  #5eb45e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col6 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col7 {
#             background-color:  #9ed89e;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col8 {
#             background-color:  #56b056;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col9 {
#             background-color:  #008000;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col10 {
#             background-color:  #d6f7d6;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col11 {
#             background-color:  #b0e2b0;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col12 {
#             background-color:  #91d091;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row5_col13 {
#             background-color:  #55af55;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row6_col2 {
#             background-color:  #a8dda8;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row6_col3 {
#             background-color:  #70be70;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row6_col4 {
#             background-color:  #caf0ca;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row6_col5 {
#             background-color:  #abdfab;
#         }    #T_3e7b8f4c_69f2_11ec_961f_185e0fc1f7a4row

# %%
en = sns.light_palette("blue", as_cmap=True)
_enr =  set_index(_enr.sort_values(by="20tft%", ascending=False, inplace=False, na_position='last'), True, True, 1)
enr_avg = _enr.mean(axis=1)
enr_avg.head()
_enr = _enr.append(enr_avg, ignore_index = True)
_enr.style.background_gradient(cmap=en)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\colors.py:512: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col1 {
#             background-color:  #c5c5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col5 {
#             background-color:  #c6c6ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col7 {
#             background-color:  #c0c0ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col9 {
#             background-color:  #bebeff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col11 {
#             background-color:  #c1c1ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col13 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col14 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col15 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col16 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col17 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col18 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col19 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col20 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col21 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col22 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col23 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col24 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col25 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col26 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col27 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row0_col28 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col1 {
#             background-color:  #d7d7ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col5 {
#             background-color:  #dadaff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col7 {
#             background-color:  #d6d6ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col9 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col11 {
#             background-color:  #dadaff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col13 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col14 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col15 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col16 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col17 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col18 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col19 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col20 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col21 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col22 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col23 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col24 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col25 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col26 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col27 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row1_col28 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col1 {
#             background-color:  #afafff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col5 {
#             background-color:  #b2b2ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col7 {
#             background-color:  #afafff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col9 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col11 {
#             background-color:  #b0b0ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col13 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col14 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col15 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col16 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col17 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col18 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col19 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col20 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col21 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col22 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col23 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col24 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col25 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col26 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col27 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row2_col28 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col1 {
#             background-color:  #a9a9ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col5 {
#             background-color:  #b0b0ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col7 {
#             background-color:  #a4a4ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col9 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col11 {
#             background-color:  #acacff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col13 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col14 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col15 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col16 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col17 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col18 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col19 {
#             background-color:  #e5e5ff;
#         }    #T_698f60e4_69f2_11ec_92ee_185e0fc1f7a4row3_col20 {
#             background-color:  #e5e5ff;
#         }    #T_698
